# %%
# !pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp39-cp39-macosx_10_9_x86_64.whl (7.2 MB)
#      |████████████████████████████████| 7.2 MB 3.2 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp39-cp39-macosx_10_9_x86_64.whl (61 kB)
#      |████████████████████████████████| 61 kB 756 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib) (2.8.1)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp39-cp39-macosx_10_10_x86_64.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 1.4 MB/s eta 0:00:01     |█████████████▌                  | 1.2 MB 1.4 MB/s eta 0:00:02     |████████████████▏               | 1.4 MB 1.4 MB/s eta 0:00:02
# Requirement already satisfied: six in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, cycler, matplotlib
# Successfully installed cycler-0.10.0 kiwisolver-1.3.1 matplotlib-3.4.2 pillow-8.2.0

# %%
# !pip install squarify

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
#      |████████████████████████████████| 285 kB 398 kB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=2.2 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from seaborn) (3.4.2)
# Requirement already satisfied: pandas>=0.23 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from seaborn) (1.2.4)
# Collecting scipy>=1.0
#   Downloading scipy-1.6.3-cp39-cp39-macosx_10_9_x86_64.whl (30.9 MB)
#      |████████████████████████████████| 30.9 MB 3.4 MB/s eta 0:00:011   |█████▏                          | 4.9 MB 1.9 MB/s eta 0:00:14     |████████████████████▍           | 19.7 MB 17.2 MB/s eta 0:00:01     |█████████████████████████████▍  | 28.4 MB 133 kB/s eta 0:00:19
# Requirement already satisfied: numpy>=1.15 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: cycler>=0.10 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.2.0)
# Requirement already satisfied: six in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/deeptha/mambaforge/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.6.3 seaborn-0.11.1

# %%
import pandas as pd
from datetime import timedelta
import matplotlib.pyplot as plt
import squarify
import seaborn as sns

# %%
df = pd.read_csv('transaction.csv', encoding = "ISO-8859-1")
# Convert InvoiceDate from object to datetime format
df['createdAt'] = pd.to_datetime(df['createdAt'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256334 entries, 0 to 256333
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   payerAccountNumber      256294 non-null  float64
#  1   status                  256334 non-null  int64
#  2   originalAmount          256334 non-null  float64
#  3   type                    256334 non-null  int64
#  4   currency                256334 non-null  int64
#  5   createdAt               256334 non-null  datetime64[ns]
#  6   payeeIdTransformed      256334 non-null  int64
#  7   payerIdTransformed      256334 non-null  int64
#  8   is_fraud                256334 non-null  int64
#  9   amount_high             256334 non-null  int64
#  10  bank_approved           256334 non-null  int64
#  11  bank_err                256334 non-null  int64
#  12  bank_invalid_card       256334 non-null  int64
#  13  bank_insufficient_fund  256334 non-null  int64
#  14  bank_do_not_honor       256334 non-null  int64
#  15  bank_lost_card          256334 non-null  int64
#  16  initialized_api         256334 non-null  int64
#  17  initialized_session     256334 non-null  int64
#  18  initialized_plugin      256334 non-null  int64
#  19  initialized_ext_api     256334 non-null  int64
#  20  initialized_ipg         256334 non-null  int64
#  21  channel_master          256334 non-null  int64
#  22  channel_visa            256334 non-null  int64
#  23  channel_amex            256334 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(21)
# memory usage: 46.9 MB

# %%
#get the snpshot of date 
snapshot_date = df['createdAt'].max() + timedelta(days=1)
print(snapshot_date)
# Out:
# 2021-04-27 14:26:05

# %%
# Grouping by payer Id
data_process = df.groupby(['payerIdTransformed','payerAccountNumber']).agg({
        'createdAt': lambda x: (snapshot_date - x.max()).days,
        'payerAccountNumber': 'count',
        'originalAmount': 'sum',
        'bank_approved':'sum',
        'bank_err':'sum',
        'bank_invalid_card':'sum',
        'bank_insufficient_fund':'sum',
        'bank_do_not_honor':'sum',
        'bank_lost_card':'sum',
        'amount_high':'sum',
        'is_fraud':'sum',
        'channel_master':'sum',
        'channel_visa':'sum',
        'channel_amex':'sum'
})

# %%
# Rename the columns 
data_process.rename(columns={'createdAt': 'recency',
                         'payerAccountNumber': 'frequency',
                         'originalAmount': 'total_value'}, inplace=True)

# %%
data_process.head(10)
# Out:
#                                        recency  frequency  total_value  \
# payerIdTransformed payerAccountNumber
# 170                4.216892e+09            124         34     213542.0
#                    4.691767e+09            256          6        611.0
# 171                4.157394e+09            261          3         30.0
#                    4.216892e+09            235          6        561.0
# 172                4.511936e+09            258         12       1316.0
# 173                4.216892e+09            255          9        180.0
# 174                5.404507e+09            126         11     221198.0
# 175                4.216892e+09            235          4      20080.0
# 176                5.288431e+09            190          4     130735.0
#                    5.290917e+09            240          2         20.0
#
#                                        bank_approved  bank_err  \
# payerIdTransformed payerAccountNumber
# 170                4.216892e+09                   18         0
#                    4.691767e+09                    0         0
# 171                4.157394e+09                    1         0
#                    4.216892e+09                    3         0
# 172                4.511936e+09                    1         0
# 173                4.216892e+09                    7         0
# 174                5.404507e+09                    0         0
# 175                4.216892e+09                    3         0
# 176                5.288431e+09                    2         0
#                    5.290917e+09                    0         0
#
#                                        bank_invalid_card  \
# payerIdTransformed payerAccountNumber
# 170                4.216892e+09                        4
#                    4.691767e+09                        0
# 171                4.157394e+09                        0
#                    4.216892e+09                        0
# 172                4.511936e+09                        0
# 173                4.216892e+09                        0
# 174                5.404507e+09                        3
# 175                4.216892e+09                        0
# 176                5.288431e+09                        0
#                    5.290917e+09                        0
#
#                                        bank_insufficient_fund  \
# payerIdTransformed payerAccountNumber
# 170                4.216892e+09                             1
#                    4.691767e+09                             1
# 171                4.157394e+09                             0
#                    4.216892e+09                             0
# 172                4.511936e+09                             0
# 173                4.216892e+09                             0
# 174                5.404507e+09                             1
# 175                4.216892e+09                             0
# 176                5.288431e+09                             0
#                    5.290917e+09                             0
#
#                                        bank_do_not_honor  bank_lost_card  \
# payerIdTransformed payerAccountNumber
# 170                4.216892e+09                       11               0
#                    4.691767e+09                        5               0
# 171                4.157394e+09                        2               0
#                    4.216892e+09                        3               0
# 172                4.511936e+09                       11               0
# 173                4.216892e+09                        2               0
# 174                5.404507e+09                        7               0
# 175                4.216892e+09                        1               0
# 176                5.288431e+09                        2               0
#                    5.290917e+09                        2               0
#
#                                        amount_high  is_fraud  channel_master  \
# payerIdTransformed payerAccountNumber
# 170                4.216892e+09                  4        30              34
#                    4.691767e+09                  0         6               6
# 171                4.157394e+09                  0         3               3
#                    4.216892e+09                  0         6               6
# 172                4.511936e+09                  0        12              12
# 173                4.216892e+09                  0         9               9
# 174                5.404507e+09                  4         8              11
# 175                4.216892e+09                  1         4               4
# 176                5.288431e+09                  2         4               4
#                    5.290917e+09                  0         2               2
#
#                                        channel_visa  channel_amex
# payerIdTransformed payerAccountNumber
# 170                4.216892e+09                   0             0
#                    4.691767e+09                   0             0
# 171                4.157394e+09                   0             0
#                    4.216892e+09                   0             0
# 172                4.511936e+09                   0             0
# 173                4.216892e+09                   0             0
# 174                5.404507e+09                   0             0
# 175                4.216892e+09                   0             0
# 176                5.288431e+09                   0             0
#                    5.290917e+09                   0             0

# %%
data_process.to_csv('transaction_data_process.csv',index=False)

# %%
print('{:,} rows; {:,} columns'
      .format(data_process.shape[0], data_process.shape[1]))
# Out:
# 41,276 rows; 14 columns

# %%
plt.figure(figsize=(12,10))
# Plot distribution of R
plt.subplot(3, 1, 1); sns.histplot(data_process['recency'])

# Plot distribution of F
plt.subplot(3, 1, 2); sns.histplot(data_process['frequency'])
plt.ylim(0, 20000)
plt.xlim(0, 80)

# Plot distribution of M
plt.subplot(3, 1, 3); sns.histplot(data_process['total_value'])
plt.ylim(0, 10000)
plt.xlim(0, 320000)

plt.show()
